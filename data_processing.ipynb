# %% [markdown]
# ### Data Preprocessing Steps

# %%
import pandas as pd
#read file
df=pd.read_csv('loan_small.csv')
df
# Out:
#      Loan_ID  Gender  ApplicantIncome  CoapplicantIncome  LoanAmount   Area  \
# 0   LP001002     NaN           5849.0                0.0         NaN  urban
# 1   LP001003    Male           4583.0                NaN       128.0   semi
# 2   LP001005    Male           3000.0                0.0        66.0    NaN
# 3   LP001006  Female           2583.0             2358.0       120.0   semi
# 4   LP001008    Male              NaN                0.0       141.0  urban
# 5   LP001011    Male           5417.0             4196.0       267.0   semi
# 6   LP001013    Male           2333.0             1516.0         NaN  rural
# 7   LP001014  Female           3036.0             2504.0       158.0   semi
# 8   LP001018    Male           4006.0             1526.0       168.0  rural
# 9   LP001020    Male          12841.0            10968.0       349.0   semi
# 10  LP001024  Female           3200.0              700.0        70.0  urban
# ...

# %%
#access dataset
df_new=df.iloc[0:3,1:3]
df_new
# Out:
#   Gender  ApplicantIncome
# 0    NaN           5849.0
# 1   Male           4583.0
# 2   Male           3000.0

# %%
#access using col names
subcoln=df[['Gender','ApplicantIncome']][0:3]
subcoln
# Out:
#   Gender  ApplicantIncome
# 0    NaN           5849.0
# 1   Male           4583.0
# 2   Male           3000.0

# %%
df_tb=pd.read_csv('loan_small_tsv.txt',sep='\t')
df_tb
# Out:
#      Loan_ID  Gender  ApplicantIncome  CoapplicantIncome  LoanAmount   Area  \
# 0   LP001002     NaN           5849.0                0.0         NaN  urban
# 1   LP001003    Male           4583.0                NaN       128.0   semi
# 2   LP001005    Male           3000.0                0.0        66.0    NaN
# 3   LP001006  Female           2583.0             2358.0       120.0   semi
# 4   LP001008    Male              NaN                0.0       141.0  urban
# 5   LP001011    Male           5417.0             4196.0       267.0   semi
# 6   LP001013    Male           2333.0             1516.0         NaN   semi
# 7   LP001014  Female           3036.0             2504.0       158.0   semi
# 8   LP001018    Male           4006.0             1526.0       168.0  rural
# 9   LP001020    Male          12841.0            10968.0       349.0   semi
# 10  LP001024  Female           3200.0              700.0        70.0  urban
# ...

# %%
df.head(5)
# Out:
#     Loan_ID  Gender  ApplicantIncome  CoapplicantIncome  LoanAmount   Area  \
# 0  LP001002     NaN           5849.0                0.0         NaN  urban
# 1  LP001003    Male           4583.0                NaN       128.0   semi
# 2  LP001005    Male           3000.0                0.0        66.0    NaN
# 3  LP001006  Female           2583.0             2358.0       120.0   semi
# 4  LP001008    Male              NaN                0.0       141.0  urban
#
#   Loan_Status
# 0           Y
# 1           N
# 2           Y
# 3         NaN
# 4           Y

# %%
df.shape
# Out:
# (16, 7)

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'ApplicantIncome', 'CoapplicantIncome',
#        'LoanAmount', 'Area', 'Loan_Status'],
#       dtype='object')

# %%
#findout columns with missing values
df.isnull().sum(axis=0)
# Out:
# Loan_ID              0
# Gender               1
# ApplicantIncome      2
# CoapplicantIncome    1
# LoanAmount           3
# Area                 1
# Loan_Status          1
# dtype: int64

# %%
#data preprocessing
#remove all rec with nan
cleandata=df.dropna()

# %%
cleandata
# Out:
#      Loan_ID  Gender  ApplicantIncome  CoapplicantIncome  LoanAmount   Area  \
# 5   LP001011    Male           5417.0             4196.0       267.0   semi
# 7   LP001014  Female           3036.0             2504.0       158.0   semi
# 8   LP001018    Male           4006.0             1526.0       168.0  rural
# 9   LP001020    Male          12841.0            10968.0       349.0   semi
# 10  LP001024  Female           3200.0              700.0        70.0  urban
# 11  LP001027    Male           2500.0             1840.0       109.0  urban
# 13  LP001029    Male           1853.0             2840.0       114.0  urban
# 14  LP001030    Male           1299.0             1086.0        17.0   semi
# 15  LP001032    Male           4950.0                0.0       125.0   semi
#
#    Loan_Status
# 5            Y
# 7            N
# 8            Y
# 9            N
# 10           Y
# 11           Y
# 13           N
# 14           Y
# 15           Y

# %%
cleandata=df.dropna(subset=['Loan_Status'])

# %%
cleandata.shape
# Out:
# (15, 7)

# %%
dt=df.copy()

# %%
dt
# Out:
#      Loan_ID  Gender  ApplicantIncome  CoapplicantIncome  LoanAmount   Area  \
# 0   LP001002     NaN           5849.0                0.0         NaN  urban
# 1   LP001003    Male           4583.0                NaN       128.0   semi
# 2   LP001005    Male           3000.0                0.0        66.0    NaN
# 3   LP001006  Female           2583.0             2358.0       120.0   semi
# 4   LP001008    Male              NaN                0.0       141.0  urban
# 5   LP001011    Male           5417.0             4196.0       267.0   semi
# 6   LP001013    Male           2333.0             1516.0         NaN  rural
# 7   LP001014  Female           3036.0             2504.0       158.0   semi
# 8   LP001018    Male           4006.0             1526.0       168.0  rural
# 9   LP001020    Male          12841.0            10968.0       349.0   semi
# 10  LP001024  Female           3200.0              700.0        70.0  urban
# ...

# %%
cols=['Gender','Area','Loan_Status']

# %%
dt[cols]
# Out:
#     Gender   Area Loan_Status
# 0      NaN  urban           Y
# 1     Male   semi           N
# 2     Male    NaN           Y
# 3   Female   semi         NaN
# 4     Male  urban           Y
# 5     Male   semi           Y
# 6     Male  rural           Y
# 7   Female   semi           N
# 8     Male  rural           Y
# 9     Male   semi           N
# 10  Female  urban           Y
# 11    Male  urban           Y
# 12  Female  urban           Y
# 13    Male  urban           N
# 14    Male   semi           Y
# 15    Male   semi           Y

# %%
dt[cols]=dt[cols].fillna(dt.mode().iloc[0])

# %%
dt.isnull().sum(axis=0)
# Out:
# Loan_ID              0
# Gender               0
# ApplicantIncome      2
# CoapplicantIncome    1
# LoanAmount           3
# Area                 0
# Loan_Status          0
# dtype: int64

# %%
cols2=['ApplicantIncome','CoapplicantIncome','LoanAmount']
dt[cols2]
# Out:
#     ApplicantIncome  CoapplicantIncome  LoanAmount
# 0       5849.000000           0.000000  140.923077
# 1       4583.000000        2509.333333  128.000000
# 2       3000.000000           0.000000   66.000000
# 3       2583.000000        2358.000000  120.000000
# 4       4103.571429           0.000000  141.000000
# 5       5417.000000        4196.000000  267.000000
# 6       2333.000000        1516.000000  140.923077
# 7       3036.000000        2504.000000  158.000000
# 8       4006.000000        1526.000000  168.000000
# 9      12841.000000       10968.000000  349.000000
# 10      3200.000000         700.000000   70.000000
# 11      2500.000000        1840.000000  109.000000
# 12      4103.571429        8106.000000  140.923077
# 13      1853.000000        2840.000000  114.000000
# 14      1299.000000        1086.000000   17.000000
# 15      4950.000000           0.000000  125.000000

# %%
dt[cols2]=dt[cols2].fillna(dt.mean())
# Out:
# C:\Users\smrit\AppData\Local\Temp\ipykernel_34628\3476645402.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dt[cols2]=dt[cols2].fillna(dt.mean())

# %%
dt.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Area                 0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# ### Label Encoding for Categorical Data

# %%
dt.dtypes
# Out:
# Loan_ID               object
# Gender                object
# ApplicantIncome      float64
# CoapplicantIncome    float64
# LoanAmount           float64
# Area                  object
# Loan_Status           object
# dtype: object

# %%
#change datatypes for string cols
cols=['Gender','Area','Loan_Status']
dt[cols]=dt[cols].astype('category')

# %%
dt.dtypes
# Out:
# Loan_ID                object
# Gender               category
# ApplicantIncome       float64
# CoapplicantIncome     float64
# LoanAmount            float64
# Area                 category
# Loan_Status          category
# dtype: object

# %%
for c in cols:
    dt[c]=dt[c].cat.codes

# %%
dt
# Out:
#      Loan_ID  Gender  ApplicantIncome  CoapplicantIncome  LoanAmount  Area  \
# 0   LP001002       1      5849.000000           0.000000  140.923077     2
# 1   LP001003       1      4583.000000        2509.333333  128.000000     1
# 2   LP001005       1      3000.000000           0.000000   66.000000     1
# 3   LP001006       0      2583.000000        2358.000000  120.000000     1
# 4   LP001008       1      4103.571429           0.000000  141.000000     2
# 5   LP001011       1      5417.000000        4196.000000  267.000000     1
# 6   LP001013       1      2333.000000        1516.000000  140.923077     0
# 7   LP001014       0      3036.000000        2504.000000  158.000000     1
# 8   LP001018       1      4006.000000        1526.000000  168.000000     0
# 9   LP001020       1     12841.000000       10968.000000  349.000000     1
# 10  LP001024       0      3200.000000         700.000000   70.000000     2
# ...

# %% [markdown]
# ### Hot Encoding for categorical columns

# %% [markdown]
# Label Encoding created another problem.we converted them to numbers, they will now follow all the properties of numbers and all
# the possible operations of numbers are possible on them.So in mathematics, three is greater than two and two is greater than one.
# So essentially what we are seeing here is that rural is greater than semi urban and semi urban is greater than urban.
# Which is not the case.

# %%
#create dummy variables for Hot encoding

df2=df.drop(['Loan_ID'],axis=1)

# %%
df2=pd.get_dummies(df2)

# %%
df2.shape
# Out:
# (16, 10)

# %%
df.shape
# Out:
# (16, 7)

# %%
df2
# Out:
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Gender_Female  \
# 0            5849.0                0.0         NaN              0
# 1            4583.0                NaN       128.0              0
# 2            3000.0                0.0        66.0              0
# 3            2583.0             2358.0       120.0              1
# 4               NaN                0.0       141.0              0
# 5            5417.0             4196.0       267.0              0
# 6            2333.0             1516.0         NaN              0
# 7            3036.0             2504.0       158.0              1
# 8            4006.0             1526.0       168.0              0
# 9           12841.0            10968.0       349.0              0
# 10           3200.0              700.0        70.0              1
# 11           2500.0             1840.0       109.0              0
# 12              NaN             8106.0         NaN              1
# ...

# %% [markdown]
# ### what is normalization?
# It simply means adjusting the values on different scales to a common scale.

# %%
clndata=df.dropna()

# %%
clndata
# Out:
#      Loan_ID  Gender  ApplicantIncome  CoapplicantIncome  LoanAmount   Area  \
# 5   LP001011    Male           5417.0             4196.0       267.0   semi
# 7   LP001014  Female           3036.0             2504.0       158.0   semi
# 8   LP001018    Male           4006.0             1526.0       168.0  rural
# 9   LP001020    Male          12841.0            10968.0       349.0   semi
# 10  LP001024  Female           3200.0              700.0        70.0  urban
# 11  LP001027    Male           2500.0             1840.0       109.0  urban
# 13  LP001029    Male           1853.0             2840.0       114.0  urban
# 14  LP001030    Male           1299.0             1086.0        17.0   semi
# 15  LP001032    Male           4950.0                0.0       125.0   semi
#
#    Loan_Status
# 5            Y
# 7            N
# 8            Y
# 9            N
# 10           Y
# 11           Y
# 13           N
# 14           Y
# 15           Y

# %%
#extract the three numerical columns
data_to_scale=clndata.iloc[:,2:5]

# %%
data_to_scale
# Out:
#     ApplicantIncome  CoapplicantIncome  LoanAmount
# 5            5417.0             4196.0       267.0
# 7            3036.0             2504.0       158.0
# 8            4006.0             1526.0       168.0
# 9           12841.0            10968.0       349.0
# 10           3200.0              700.0        70.0
# 11           2500.0             1840.0       109.0
# 13           1853.0             2840.0       114.0
# 14           1299.0             1086.0        17.0
# 15           4950.0                0.0       125.0

# %%
#import standard scalar
from sklearn.preprocessing import StandardScaler

# %%
scalar_=StandardScaler()

# %%
ss_scalar_=scalar_.fit_transform(data_to_scale)

# %%
ss_scalar_
# Out:
# array([[ 0.32879835,  0.43390231,  1.1995349 ],
#        [-0.40126276, -0.11198867,  0.05261118],
#        [-0.10384182, -0.4275214 ,  0.15783354],
#        [ 2.60514177,  2.61875676,  2.06235824],
#        [-0.35097716, -0.69401428, -0.87334558],
#        [-0.56561083, -0.32621539, -0.46297838],
#        [-0.76399367, -0.00358478, -0.4103672 ],
#        [-0.9338609 , -0.56947886, -1.43102409],
#        [ 0.18560703, -0.9198557 , -0.29462261]])

# %% [markdown]
# #### minmax scaling

# %%
from sklearn.preprocessing import minmax_scale

# %%
mm_scalar=minmax_scale(data_to_scale)

# %%
mm_scalar
# Out:
# array([[0.35678392, 0.38256747, 0.75301205],
#        [0.15049385, 0.22830051, 0.4246988 ],
#        [0.23453474, 0.13913202, 0.45481928],
#        [1.        , 1.        , 1.        ],
#        [0.16470282, 0.06382203, 0.15963855],
#        [0.10405476, 0.16776076, 0.27710843],
#        [0.04799861, 0.25893508, 0.29216867],
#        [0.        , 0.09901532, 0.        ],
#        [0.31632299, 0.        , 0.3253012 ]])

# %% [markdown]
# ### Train and Test Set

# %%
df3=df.copy()

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'ApplicantIncome', 'CoapplicantIncome',
#        'LoanAmount', 'Area', 'Loan_Status'],
#       dtype='object')

# %%
df3=df3.drop(['Loan_ID'],axis=1)

# %%
df3
# Out:
#     Gender  ApplicantIncome  CoapplicantIncome  LoanAmount   Area Loan_Status
# 0      NaN           5849.0                0.0         NaN  urban           Y
# 1     Male           4583.0                NaN       128.0   semi           N
# 2     Male           3000.0                0.0        66.0    NaN           Y
# 3   Female           2583.0             2358.0       120.0   semi         NaN
# 4     Male              NaN                0.0       141.0  urban           Y
# 5     Male           5417.0             4196.0       267.0   semi           Y
# 6     Male           2333.0             1516.0         NaN  rural           Y
# 7   Female           3036.0             2504.0       158.0   semi           N
# 8     Male           4006.0             1526.0       168.0  rural           Y
# 9     Male          12841.0            10968.0       349.0   semi           N
# 10  Female           3200.0              700.0        70.0  urban           Y
# ...

# %%
cols=['Gender','Area','Loan_Status']

df3[cols]=df3[cols].fillna(df3.mode().iloc[0])

# %%
df3.isnull().sum()
# Out:
# Gender               0
# ApplicantIncome      2
# CoapplicantIncome    1
# LoanAmount           3
# Area                 0
# Loan_Status          0
# dtype: int64

# %%
cols1=['ApplicantIncome','CoapplicantIncome','LoanAmount']
df3[cols1]=df3[cols1].fillna(df3.mean())
# Out:
# C:\Users\smrit\AppData\Local\Temp\ipykernel_34628\4205734806.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df3[cols1]=df3[cols1].fillna(df3.mean())

# %%
df3.isnull().sum()
# Out:
# Gender               0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Area                 0
# Loan_Status          0
# dtype: int64

# %%
df3=pd.get_dummies(df3,drop_first=True)

# %%
df3
# Out:
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Gender_Male  Area_semi  \
# 0       5849.000000           0.000000  140.923077            1          0
# 1       4583.000000        2509.333333  128.000000            1          1
# 2       3000.000000           0.000000   66.000000            1          1
# 3       2583.000000        2358.000000  120.000000            0          1
# 4       4103.571429           0.000000  141.000000            1          0
# 5       5417.000000        4196.000000  267.000000            1          1
# 6       2333.000000        1516.000000  140.923077            1          0
# 7       3036.000000        2504.000000  158.000000            0          1
# 8       4006.000000        1526.000000  168.000000            1          0
# 9      12841.000000       10968.000000  349.000000            1          1
# 10      3200.000000         700.000000   70.000000            0          0
# ...

# %%
data_toscl=df3.iloc[:,0:3]
from sklearn.preprocessing import StandardScaler
#from sklearn.preprocessing import StandardScaler
sclar_=StandardScaler()
ss_scalar_=sclar_.fit_transform(data_toscl)

# %%
df3
# Out:
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Gender_Male  Area_semi  \
# 0       5849.000000           0.000000  140.923077            1          0
# 1       4583.000000        2509.333333  128.000000            1          1
# 2       3000.000000           0.000000   66.000000            1          1
# 3       2583.000000        2358.000000  120.000000            0          1
# 4       4103.571429           0.000000  141.000000            1          0
# 5       5417.000000        4196.000000  267.000000            1          1
# 6       2333.000000        1516.000000  140.923077            1          0
# 7       3036.000000        2504.000000  158.000000            0          1
# 8       4006.000000        1526.000000  168.000000            1          0
# 9      12841.000000       10968.000000  349.000000            1          1
# 10      3200.000000         700.000000   70.000000            0          0
# ...

# %%
x=df3.iloc[:,:-1]
y=df3.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=1234)

# %%
# Out:
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Gender_Male  Area_semi  \
# 13      1853.000000             2840.0  114.000000            1          0
# 11      2500.000000             1840.0  109.000000            1          0
# 0       5849.000000                0.0  140.923077            1          0
# 12      4103.571429             8106.0  140.923077            0          0
#
#     Area_urban
# 13           1
# 11           1
# 0            1
# 12           1
